# %% [markdown]
# # Преобразование Хафа

# %% [markdown]
# Задача состоит в обнаружении геометрических примитивов на изображении.
#
# 1. Обнаружения линий на изображении с помощью преобразования Хафа.
# 2. Обнаружения окружностей на изображении с помощью преобразования Хафа.

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Logs-1

# %%
src = cv.imread("task_2_images/logs-1.jpg")
src = cv.cvtColor(src, cv.COLOR_BGR2RGB)
gray = cv.cvtColor(src, cv.COLOR_RGB2GRAY)
gray = cv.blur(gray, (3, 3)) # Apply blur with a 3x3 kernel
detected_circles = cv.HoughCircles(gray,
                   cv.HOUGH_GRADIENT,
                   1.12,  # Inverse ratio of the accumulator resolution to the image resolution
                   10, # Minimum distance between the centers of the detected circles
                   param1 = 480, # The higher threshold of the two passed to the Canny edge detector
                   param2 = 10,  # The accumulator threshold for the circle centers at the detection stage
                   minRadius = 5, maxRadius = 15)

# %%
image = src.copy()
pipes_count = 0
if detected_circles is not None:
    detected_circles = np.uint16(np.around(detected_circles)) # Convert circle metadata to integers

    for points in detected_circles[0, :]:
        a, b, r = points[0], points[1], points[2]

        cv.circle(image, (a, b), r, (0, 255, 0), 2)

        # Draw a small circle (of radius 1) to show the center.
        cv.circle(image, (a, b), 1, (255, 0, 0), 3)

        pipes_count += 1

print("Total logs: ", pipes_count)
plt.imshow(image)
# Out:
# Total logs:  76

# %% [markdown]
# Logs-2

# %%
src = cv.imread("task_2_images/logs-2.jpg")
src = cv.cvtColor(src, cv.COLOR_BGR2RGB)
gray = cv.cvtColor(src, cv.COLOR_RGB2GRAY)
gray = cv.blur(gray, (3, 3)) # Apply blur with a 3x3 kernel
detected_circles = cv.HoughCircles(gray,
                   cv.HOUGH_GRADIENT,
                   1,  # Inverse ratio of the accumulator resolution to the image resolution
                   17, # Minimum distance between the centers of the detected circles
                   param1 = 560, # The higher threshold of the two passed to the Canny edge detector
                   param2 = 10,  # The accumulator threshold for the circle centers at the detection stage
                   minRadius = 5, maxRadius = 17)

# %%
image = src.copy()
pipes_count = 0
if detected_circles is not None:
    detected_circles = np.uint16(np.around(detected_circles)) # Convert circle metadata to integers

    for points in detected_circles[0, :]:
        a, b, r = points[0], points[1], points[2]

        cv.circle(image, (a, b), r, (0, 255, 0), 2)

        # Draw a small circle (of radius 1) to show the center.
        cv.circle(image, (a, b), 1, (255, 0, 0), 3)

        pipes_count += 1

print("Total logs: ", pipes_count)
plt.imshow(image)
# Out:
# Total logs:  119

# %% [markdown]
# Pipes-4

# %%
src = cv.imread("task_2_images/pipes-4.jpg")
src = cv.cvtColor(src, cv.COLOR_BGR2RGB)

gray = cv.cvtColor(src, cv.COLOR_RGB2GRAY)
gray = cv.blur(gray, (3, 3)) # Apply blur with a 3x3 kernel

detected_circles = cv.HoughCircles(gray,
                   cv.HOUGH_GRADIENT,
                   1,  # Inverse ratio of the accumulator resolution to the image resolution
                   15, # Minimum distance between the centers of the detected circles
                   param1 = 200, # The higher threshold of the two passed to the Canny edge detector
                   param2 = 25,  # The accumulator threshold for the circle centers at the detection stage
                   minRadius = 0, maxRadius = 20)

# %%
image = src.copy()
pipes_count = 0
if detected_circles is not None:
    detected_circles = np.uint16(np.around(detected_circles)) # Convert circle metadata to integers

    for points in detected_circles[0, :]:
        a, b, r = points[0], points[1], points[2]

        cv.circle(image, (a, b), r, (0, 255, 0), 2)

        # Draw a small circle (of radius 1) to show the center.
        cv.circle(image, (a, b), 1, (255, 0, 0), 3)

        pipes_count += 1

print("Total pipes: ", pipes_count)
plt.imshow(image)
# Out:
# Total pipes:  78

# %% [markdown]
# Pipes-5

# %%
src = cv.imread("task_2_images/pipes-5.jpg")
src = cv.cvtColor(src, cv.COLOR_BGR2RGB)
gray = cv.cvtColor(src, cv.COLOR_RGB2GRAY)
gray = cv.blur(gray, (3, 3)) # Apply blur with a 3x3 kernel
detected_circles = cv.HoughCircles(gray,
                   cv.HOUGH_GRADIENT,
                   1,  # Inverse ratio of the accumulator resolution to the image resolution
                   15, # Minimum distance between the centers of the detected circles
                   param1 = 200, # The higher threshold of the two passed to the Canny edge detector
                   param2 = 14,  # The accumulator threshold for the circle centers at the detection stage
                   minRadius = 0, maxRadius = 20)

detected_circles2 = cv.HoughCircles(gray,
                   cv.HOUGH_GRADIENT,
                   1,  # Inverse ratio of the accumulator resolution to the image resolution
                   40, # Minimum distance between the centers of the detected circles
                   param1 = 200, # The higher threshold of the two passed to the Canny edge detector
                   param2 = 25,  # The accumulator threshold for the circle centers at the detection stage
                   minRadius = 70, maxRadius = 80)

# %%
image = src.copy()
pipes_count = 0
if detected_circles is not None:
    detected_circles = np.uint16(np.around(detected_circles)) # Convert circle metadata to integers

    for points in detected_circles[0, :]:
        a, b, r = points[0], points[1], points[2]

        cv.circle(image, (a, b), r, (0, 255, 0), 2)

        # Draw a small circle (of radius 1) to show the center.
        cv.circle(image, (a, b), 1, (255, 0, 0), 3)

        pipes_count += 1
        
if detected_circles2 is not None:
    detected_circles2 = np.uint16(np.around(detected_circles2)) # Convert circle metadata to integers

    for points in detected_circles2[0, :]:
        a, b, r = points[0], points[1], points[2]

        cv.circle(image, (a, b), r, (0, 255, 0), 2)

        # Draw a small circle (of radius 1) to show the center.
        cv.circle(image, (a, b), 1, (255, 0, 0), 3)

        pipes_count += 1
print("Total pipes: ", pipes_count)
plt.imshow(image)
# Out:
# Total pipes:  163

# %% [markdown]
# Pipes-6

# %%
src = cv.imread("task_2_images/pipes-6.jpg")
src = cv.cvtColor(src, cv.COLOR_BGR2RGB)
gray = cv.cvtColor(src, cv.COLOR_RGB2GRAY)
gray = cv.blur(gray, (3, 3)) # Apply blur with a 3x3 kernel
detected_circles = cv.HoughCircles(gray,
                   cv.HOUGH_GRADIENT,
                   1,  # Inverse ratio of the accumulator resolution to the image resolution
                   15, # Minimum distance between the centers of the detected circles
                   param1 = 200, # The higher threshold of the two passed to the Canny edge detector
                   param2 = 20,  # The accumulator threshold for the circle centers at the detection stage
                   minRadius = 0, maxRadius = 22)

detected_circles2 = cv.HoughCircles(gray,
                   cv.HOUGH_GRADIENT,
                   1,  # Inverse ratio of the accumulator resolution to the image resolution
                   40, # Minimum distance between the centers of the detected circles
                   param1 = 300, # The higher threshold of the two passed to the Canny edge detector
                   param2 = 27,  # The accumulator threshold for the circle centers at the detection stage
                   minRadius = 40, maxRadius = 60)

detected_circles3 = cv.HoughCircles(gray,
                   cv.HOUGH_GRADIENT,
                   1,  # Inverse ratio of the accumulator resolution to the image resolution
                  80, # Minimum distance between the centers of the detected circles
                   param1 = 250, # The higher threshold of the two passed to the Canny edge detector
                   param2 = 30,  # The accumulator threshold for the circle centers at the detection stage
                   minRadius = 110, maxRadius = 130)

# %%
image = src.copy()
pipes_count = 0
if detected_circles is not None:
    detected_circles = np.uint16(np.around(detected_circles)) # Convert circle metadata to integers

    for points in detected_circles[0, :]:
        a, b, r = points[0], points[1], points[2]

        cv.circle(image, (a, b), r, (0, 255, 0), 2)

        # Draw a small circle (of radius 1) to show the center.
        cv.circle(image, (a, b), 1, (255, 0, 0), 3)

        pipes_count += 1

if detected_circles2 is not None:
    detected_circles2 = np.uint16(np.around(detected_circles2)) # Convert circle metadata to integers

    for points in detected_circles2[0, :]:
        a, b, r = points[0], points[1], points[2]

        cv.circle(image, (a, b), r, (0, 255, 0), 2)

        # Draw a small circle (of radius 1) to show the center.
        cv.circle(image, (a, b), 1, (255, 0, 0), 3)

        pipes_count += 1

if detected_circles3 is not None:
    detected_circles3 = np.uint16(np.around(detected_circles3)) # Convert circle metadata to integers

    for points in detected_circles3[0, :]:
        a, b, r = points[0], points[1], points[2]

        cv.circle(image, (a, b), r, (0, 255, 0), 2)

        # Draw a small circle (of radius 1) to show the center.
        cv.circle(image, (a, b), 1, (255, 0, 0), 3)

        pipes_count += 1

print("Total pipes: ", pipes_count)
plt.imshow(image)
# Out:
# Total pipes:  120
